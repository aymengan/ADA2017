# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Task-1.-Compiling-Ebola-Data"><span class="toc-item-num">Task 1.&nbsp;&nbsp;</span>Compiling Ebola Data</a></div>
#  <div class="lev1"><a href="#Task-2.-RNA-Sequences"><span class="toc-item-num">Task 2.&nbsp;&nbsp;</span>RNA Sequences</a></div>
#  <div class="lev1"><a href="#Task-3.-Class-War-in-Titanic"><span class="toc-item-num">Task 3.&nbsp;&nbsp;</span>Class War in Titanic</a></div></p>

# %%
DATA_FOLDER = r'C:\Users\User\git\ADA2017-Tutorials\02-IntrotoPandas\Data' # Use the data folder provided in Tutorial 02 - Intro to Pandas.

# %% [markdown]
# ## Task 1. Compiling Ebola Data
#
# The `DATA_FOLDER/ebola` folder contains summarized reports of Ebola cases from three countries (Guinea, Liberia and Sierra Leone) during the recent outbreak of the disease in West Africa. For each country, there are daily reports that contain various information about the outbreak in several cities in each country.
#
# Use pandas to import these data files into a single `Dataframe`.
# Using this `DataFrame`, calculate for *each country*, the *daily average* per month of *new cases* and *deaths*.
# Make sure you handle all the different expressions for *new cases* and *deaths* that are used in the reports.

# %%
import pandas as pd
import numpy as np
import glob

# %%
guinea_folder = r'C:\Users\User\git\ADA2017-Tutorials\02 - Intro to Pandas\Data\ebola\guinea_data'

# %%
all_files_guinea = glob.glob(guinea_folder + "/*.csv")

# %%
frame = pd.DataFrame()
list_ = []
for file_ in all_files_guinea:
    data = pd.read_csv(file_,parse_dates=['Date'], header=0)
    list_.append(data)
frame = pd.concat(list_)

# %%
filtered_data = frame.loc[frame['Description'].apply(func=lambda x: ('new cases' in x.lower() or 'new deaths' in x.lower()) and 'total' not in x.lower()),:]

# %%
guinea_data = filtered_data[['Date','Description','Totals']]

# %%
guinea_data = guinea_data.dropna()#dropna is used here to eliminate the NaN values

# %%
guinea_data['Totals'] = guinea_data['Totals'].apply(pd.to_numeric, errors='coerce')

# %%
guinea_data['Totals'].groupby([guinea_data.Date.dt.month]).agg(['sum','count','mean'])
# Out:
#       sum  count      mean
# Date
# 8     148     30  4.933333
# 9     378     96  3.937500
# 10     51      6  8.500000

# %% [markdown]
# ## Task 2. RNA Sequences
#
# In the `DATA_FOLDER/microbiome` subdirectory, there are 9 spreadsheets of microbiome data that was acquired from high-throughput RNA sequencing procedures, along with a 10<sup>th</sup> file that describes the content of each.
#
# Use pandas to import the first 9 spreadsheets into a single `DataFrame`.
# Then, add the metadata information from the 10<sup>th</sup> spreadsheet as columns in the combined `DataFrame`.
# Make sure that the final `DataFrame` has a unique index and all the `NaN` values have been replaced by the tag `unknown`.

# %%
import pandas as pd
import numpy as np
import glob

# %%
bio_folder = r'C:\Users\User\git\ADA2017-Tutorials\02 - Intro to Pandas\Data\microbiome'

# %%
all_files = glob.glob(bio_folder + "/MID?.xls")

# %%
frame = pd.DataFrame()
list_ = []
for file_ in all_files:
    data = pd.read_excel(file_, header=None)
    list_.append(data)
frame = pd.concat(list_)

# %%
frame = frame.reset_index() # I reset the index to inquire new unique indexes

# %%
metadata=pd.read_excel(bio_folder+"/metadata.xls", header=None)

# %%
result = pd.concat([frame, metadata], axis=1)

# %%
result.fillna('unknown') #replace all NaN with unknown as required
# Out:
#       index                                                  0     1        0  \
# 0         0  Archaea "Crenarchaeota" Thermoprotei Desulfuro...     7  BARCODE
# 1         1  Archaea "Crenarchaeota" Thermoprotei Desulfuro...     2     MID1
# 2         2  Archaea "Crenarchaeota" Thermoprotei Sulfoloba...     3     MID2
# 2384    269  Bacteria "Proteobacteria" Gammaproteobacteria ...     2  unknown
# 2385    270  Bacteria "Proteobacteria" Gammaproteobacteria ...     1  unknown
# 2386    271  Bacteria "Synergistetes" Synergistia Synergist...     3  unknown
# 2387    272  Bacteria "Tenericutes" Mollicutes Anaeroplasma...     1  unknown
# 2388    273  Bacteria "Tenericutes" Mollicutes Haloplasmata...    11  unknown
# 2389    274  Bacteria "Thermodesulfobacteria" Thermodesulfo...     1  unknown
# 2390    275  Bacteria "Thermodesulfobacteria" Thermodesulfo...     1  unknown
# 2391    276  Bacteria "Thermotogae" Thermotogae Thermotogal...    43  unknown
# 2392    277  Bacteria "Thermotogae" Thermotogae Thermotogal...    16  unknown
# 2393    278  Bacteria "Verrucomicrobia" Opitutae Opitutales...     1  unknown
# 2394    279  Bacteria Cyanobacteria Cyanobacteria  Chloropl...     1  unknown
# 2395    280  Bacteria Cyanobacteria Cyanobacteria  Chloropl...    10  unknown
#
#                        1        2
# 0                  GROUP   SAMPLE
# 1     EXTRACTION CONTROL  unknown
# 2                  NEC 1   tissue
# 3              Control 1   tissue
# 4                  NEC 2   tissue
# 5              Control 2   tissue
# 6                  NEC 1    stool
# 7              Control 1    stool
# 8                  NEC 2    stool
# 9              Control 2    stool
# 10               unknown  unknown
# 11               unknown  unknown
# 12               unknown  unknown
# 13               unknown  unknown
# 14               unknown  unknown
# 15               unknown  unknown
# 16               unknown  unknown
# 17               unknown  unknown
# 18               unknown  unknown
# 19               unknown  unknown
# 20               unknown  unknown
# 21               unknown  unknown
# 22               unknown  unknown
# 23               unknown  unknown
# 24               unknown  unknown
# 25               unknown  unknown
# 26               unknown  unknown
# 27               unknown  unknown
# 28               unknown  unknown
# 29               unknown  unknown
# ...                  ...      ...
# 2366             unknown  unknown
# 2367             unknown  unknown
# 2368             unknown  unknown
# 2369             unknown  unknown
# 2370             unknown  unknown
# 2371             unknown  unknown
# 2372             unknown  unknown
# 2373             unknown  unknown
# 2374             unknown  unknown
# 2375             unknown  unknown
# 2376             unknown  unknown
# 2377             unknown  unknown
# 2378             unknown  unknown
# 2379             unknown  unknown
# 2380             unknown  unknown
# 2381             unknown  unknown
# 2382             unknown  unknown
# 2383             unknown  unknown
# 2384             unknown  unknown
# 2385             unknown  unknown
# 2386             unknown  unknown
# 2387             unknown  unknown
# 2388             unknown  unknown
# 2389             unknown  unknown
# 2390             unknown  unknown
# 2391             unknown  unknown
# 2392             unknown  unknown
# 2393             unknown  unknown
# 2394             unknown  unknown
# 2395             unknown  unknown
#
# [2396 rows x 6 columns]

# %% [markdown]
# ## Task 3. Class War in Titanic
#
# Use pandas to import the data file `Data/titanic.xls`. It contains data on all the passengers that travelled on the Titanic.

# %%
from IPython.core.display import HTML
HTML(filename=DATA_FOLDER+'/titanic.html')

# %% [markdown]
# For each of the following questions state clearly your assumptions and discuss your findings:
# 1. Describe the *type* and the *value range* of each attribute. Indicate and transform the attributes that can be `Categorical`.
# 2. Plot histograms for the *travel class*, *embarkation port*, *sex* and *age* attributes. For the latter one, use *discrete decade intervals*.
# 3. Calculate the proportion of passengers by *cabin floor*. Present your results in a *pie chart*.
# 4. For each *travel class*, calculate the proportion of the passengers that survived. Present your results in *pie charts*.
# 5. Calculate the proportion of the passengers that survived by *travel class* and *sex*. Present your results in *a single histogram*.
# 6. Create 2 equally populated *age categories* and calculate survival proportions by *age category*, *travel class* and *sex*. Present your results in a `DataFrame` with unique index.

# %%
# Write your answer here
