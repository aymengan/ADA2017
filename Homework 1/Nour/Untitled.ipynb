# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob 
% matplotlib inline
sns.set_context('notebook')

sl_folder = '/Users/nourghaliaabassi/Desktop/ada/ADA2017-Tutorials/02 - Intro to Pandas/Data/ebola/sl_data'
all_files_sl = glob.glob(sl_folder + "/*.csv")

frame_l2 = pd.DataFrame()
list_l2= []
for file_ in all_files_sl:
    data = pd.read_csv(file_,parse_dates=['date'], header=0)
    list_l2.append(data)
frame_l2 = pd.concat(list_l2)
#frame_l2['Total'] = frame_l2.sum(axis=1)

for elem in filtered_l[filtered_l.columns.difference(['date','variable'])]:
     filtered_l[elem]= pd.to_numeric(filtered_l[elem], errors='coerce')
filtered_l = frame_l2.loc[frame_l2['variable'].apply(func=lambda x: (('deaths') in x.lower() or ('cum') in x.lower()) and ('suspected') not in x.lower()and ('noncase') not in x.lower() and ('followed') not in x.lower()and ('probable') not in x.lower()and ('discharges') not in x.lower() and 'new_negative' not in x.lower() and 'new_samples' not in x.lower() and 'new_contacts' not in x.lower() and 'cum_contacts' not in x.lower()),:]
filtered_l['Total'] = filtered_l.sum(axis=1)
#filtered_l_final = filtered_l['date', 'variable']
filtered_l
# Out:
# /Users/nourghaliaabassi/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     34 Military Hospital    Bo  Bo EMC Bombali Bonthe  Hastings-F/Town  \
# 8                    NaN    22     NaN       7      1              NaN
# 15                   NaN   NaN     NaN     NaN    NaN              NaN
# 16                   NaN   NaN     NaN     NaN    NaN              NaN
# 17                   NaN   NaN     NaN     NaN    NaN              NaN
# 21                   NaN    67     NaN      16     26              NaN
# 8                    NaN    23     NaN       7      1              NaN
# 15                   NaN   NaN     NaN     NaN    NaN              NaN
# ...
